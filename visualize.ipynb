# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
def plot_one(data):
    fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=(8, 6))

    ax1.plot(df.time, df.wait)
    ax1.set_ylabel('Cummulative wait time')
    
    ax2.plot(df.time, df.queue_len)
    ax2.set_ylabel('Cummulative queue length')
    
    plt.tight_layout()
    plt.show()

# %%
def plot_two(n1, d1, n2, d2):
    fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=(8, 6))

    ax1.plot(d1.time, d1.wait, label=n1)
    ax1.plot(d2.time, d2.wait, label=n2)
    ax1.set_ylabel('Cummulative wait time')
    
    ax2.plot(d1.time, d1.queue_len)
    ax2.plot(d2.time, d2.queue_len)
    ax2.set_ylabel('Cummulative queue length')
    
    plt.tight_layout()
    plt.show()

# %%
normal = pd.read_csv("normal.csv")
plot_one(normal)

# %%
ac = pd.read_csv("ac.csv")
plot_one(ac)

# %%
plot_two(normal, ac)
